# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# '1.     A study among plus2 students'$'\n''conducted. It....gsheet'
# 'ALEXA(NLP)MAIN(1).ipynb'
# 'Attendance for Mastering Internship Success Webinar.gform'
# 'Attendance for Mastering Internship Success Webinar (Responses).gsheet'
# 'Avain species.zip'
#  BOW.ipynb
# 'Colab Notebooks'
#  Data_preprocessing.py
# 'data structure_leetcode.gdoc'
# 'download (1).pdf'
# 'download (2).pdf'
# 'Email_spam_detection(final).ipynb'
# 'EXPERIMENT 1_09-01-24.docx'
# 'Experiment 10.gdoc'
# 'FakeNewsDetection [NLP] (1).ipynb'
# 'give t test and z test example.gsheet'
# "I am sharing 'acceptance' with you.pdf"
# 'ISL dataset'
# 'java  assignment_1.gdoc'
# 'M_Rebekah Russel Resume_2022410984  (1).pdf'
# 'M_Rebekah Russel Resume_2022410984  (2).pdf'
# 'M_Rebekah Russel Resume_2022410984 .pdf'
# 'projectnlp (2).gdoc'
# 'projectnlp (2).html'
# 'RebekahRussel_Resume(12-10-24).pdf'
#  Resume.gdoc
#  spam.csv
#  spam.gsheet
# 'stemming_&_Lemmatization.ipynb'
#  TF_IDF.ipynb
#  Thumbs.db

# %%
import os
import zipfile

dataset_path = "/content/drive/MyDrive/Avain species.zip"
extracted_path = "/content/Avain_Dataset"

# Extract the zip file directly
with zipfile.ZipFile(dataset_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

print("Folders inside extracted path:", os.listdir(extracted_path))
# Out:
# Folders inside extracted path: ['Heron Dataset.zip', 'Great Indian Bustard Dataset.zip', 'Albatros Dataset.zip', 'Hornbill Dataset.zip', 'Vulture.zip']

# %%
import os
import zipfile

# Path to extracted folder
extracted_path = "/content/Avain_Dataset"

# List all zip files inside the extracted folder
zip_files = [f for f in os.listdir(extracted_path) if f.endswith('.zip')]

# Extract each zip file
for zip_file in zip_files:
    zip_path = os.path.join(extracted_path, zip_file)
    extract_to = os.path.join(extracted_path, zip_file.replace('.zip', ''))  # Folder with same name as zip
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f"Extracted: {zip_file}")
# Out:
# Extracted: Heron Dataset.zip
# Extracted: Great Indian Bustard Dataset.zip
# Extracted: Albatros Dataset.zip
# Extracted: Hornbill Dataset.zip
# Extracted: Vulture.zip

# %%
import os

extracted_folders = os.listdir(extracted_path)
print("Extracted Folders:", extracted_folders)
# Out:
# Extracted Folders: ['Vulture', 'Heron Dataset.zip', 'Great Indian Bustard Dataset.zip', 'Albatros Dataset.zip', 'Heron Dataset', 'Great Indian Bustard Dataset', 'Albatros Dataset', 'Hornbill Dataset', 'Hornbill Dataset.zip', 'Vulture.zip']

# %%
import os

# Remove zip files from the extracted path
for item in os.listdir(extracted_path):
    if item.endswith(".zip"):
        os.remove(os.path.join(extracted_path, item))

# Verify cleanup
print("Remaining folders:", os.listdir(extracted_path))
# Out:
# Remaining folders: ['Vulture', 'Heron Dataset', 'Great Indian Bustard Dataset', 'Albatros Dataset', 'Hornbill Dataset']

# %%
sample_dataset = os.path.join(extracted_path, "Heron Dataset")  # Change as needed
print("Contents of sample dataset:", os.listdir(sample_dataset))
# Out:
# Contents of sample dataset: ['images.cv_pih6h5u49pfpq5hfjfzn1k']

# %%
import os

sample_folder = os.path.join(extracted_path, "Heron Dataset", "images.cv_pih6h5u49pfpq5hfjfzn1k")
print("Contents of the sample folder:", os.listdir(sample_folder))
# Out:
# Contents of the sample folder: ['data', 'meta.json']

# %%
data_folder = os.path.join(sample_folder, "data")
print("Contents of the data folder:", os.listdir(data_folder))
# Out:
# Contents of the data folder: ['val', 'test', 'train']

# %%
train_folder = os.path.join(data_folder, "train")
print("Classes in train folder:", os.listdir(train_folder))

val_folder = os.path.join(data_folder, "val")
print("Classes in val folder:", os.listdir(val_folder))

test_folder = os.path.join(data_folder, "test")
print("Classes in test folder:", os.listdir(test_folder))
# Out:
# Classes in train folder: ['heron']
# Classes in val folder: ['heron']
# Classes in test folder: ['heron']

# %%
import os
import shutil

# Define extracted dataset path
extracted_path = "/content/Avian_Dataset"  # Update if needed

# Target directory where we will merge everything
final_dataset_path = "/content/data"

# Create train, val, and test folders inside final dataset
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(final_dataset_path, split), exist_ok=True)

# %%
import os
import shutil

# Define extracted dataset path - **CORRECTED PATH**
extracted_path = "/content/Avain_Dataset"  # Update if needed

# Target directory where we will merge everything
final_dataset_path = "/content/data"

# Create train, val, and test folders inside final dataset
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(final_dataset_path, split), exist_ok=True)

# Iterate over all species folders inside the extracted dataset
for species_folder in os.listdir(extracted_path):
    species_path = os.path.join(extracted_path, species_folder, "data")

    # Check if the species folder contains the expected 'data' subfolder
    if os.path.exists(species_path):
        for split in ['train', 'val', 'test']:
            split_path = os.path.join(species_path, split)
            if os.path.exists(split_path):
                for species in os.listdir(split_path):
                    species_source = os.path.join(split_path, species)
                    species_target = os.path.join(final_dataset_path, split, species)

                    # Move or merge the species folders
                    os.makedirs(species_target, exist_ok=True)

                    for file in os.listdir(species_source):
                        shutil.move(os.path.join(species_source, file), os.path.join(species_target, file))

print(" Dataset merged successfully!")
# Out:
#  Dataset merged successfully!

# %%
import os

for split in ['train', 'val', 'test']:
    print(f"Classes in {split}: {os.listdir(os.path.join(final_dataset_path, split))}")
# Out:
# Classes in train: []
# Classes in val: []
# Classes in test: []

# %%
import os

extracted_path = "/content/Avain_Dataset"  # Update if needed

for species_folder in os.listdir(extracted_path):
    species_path = os.path.join(extracted_path, species_folder)

    # Check if "data" exists inside the species folder
    if os.path.exists(os.path.join(species_path, "data")):
        print(f"✅ {species_folder} contains a data folder.")
        for split in ['train', 'val', 'test']:
            split_path = os.path.join(species_path, "data", split)
            if os.path.exists(split_path):
                print(f"    📂 {split} contains:", os.listdir(split_path))
    else:
        print(f"❌ {species_folder} does NOT contain a data folder.")
# Out:
# ❌ Vulture does NOT contain a data folder.
# ❌ Heron Dataset does NOT contain a data folder.
# ❌ Great Indian Bustard Dataset does NOT contain a data folder.
# ❌ Albatros Dataset does NOT contain a data folder.
# ❌ Hornbill Dataset does NOT contain a data folder.

# %%
import os

extracted_path = "/content/Avain_Dataset"  # Update if needed

for species_folder in os.listdir(extracted_path):
    species_path = os.path.join(extracted_path, species_folder)
    print(f"📂 {species_folder} contains: {os.listdir(species_path)}")
# Out:
# 📂 Vulture contains: ['images.cv_aoonqxfq1z0tz8mdt4fcx']
# 📂 Heron Dataset contains: ['images.cv_pih6h5u49pfpq5hfjfzn1k']
# 📂 Great Indian Bustard Dataset contains: ['images.cv_58uuftfuqt74tiktod8s5s']
# 📂 Albatros Dataset contains: ['images.cv_3h94ibvmyf3gl9ladgou1s']
# 📂 Hornbill Dataset contains: ['images.cv_weiy3tkv7gew85n1izfg']

# %%
species_folder = os.path.join(extracted_path, "Heron Dataset", "images.cv_pih6h5u49pfpq5hfjfzn1k")
print("📂 Inside Heron Dataset:", os.listdir(species_folder))
# Out:
# 📂 Inside Heron Dataset: ['data', 'meta.json']

# %%
import os
import shutil

# Define paths
extracted_path = "/content/Avain_Dataset"  # Path where species datasets are extracted
final_dataset_path = "/content/data"  # Unified dataset location

# Create train, val, and test directories
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(final_dataset_path, split), exist_ok=True)

# Iterate over all species folders
for species_folder in os.listdir(extracted_path):
    species_path = os.path.join(extracted_path, species_folder)

    # Find the unique image folder inside each species
    for subfolder in os.listdir(species_path):
        subfolder_path = os.path.join(species_path, subfolder)

        # Ensure it contains a "data" folder
        data_path = os.path.join(subfolder_path, "data")
        if os.path.exists(data_path):
            for split in ['train', 'val', 'test']:
                split_path = os.path.join(data_path, split)
                if os.path.exists(split_path):
                    for species_name in os.listdir(split_path):
                        species_source = os.path.join(split_path, species_name)
                        species_target = os.path.join(final_dataset_path, split, species_name)

                        os.makedirs(species_target, exist_ok=True)  # Ensure target folder exists

                        for file in os.listdir(species_source):
                            src_file = os.path.join(species_source, file)
                            dst_file = os.path.join(species_target, file)

                            if os.path.isfile(src_file):  # Move only files, not folders
                                shutil.move(src_file, dst_file)

print("✅ Dataset merging completed successfully!")
# Out:
# ✅ Dataset merging completed successfully!

# %%
for split in ['train', 'val', 'test']:
    print(f"Classes in {split}: {os.listdir(os.path.join(final_dataset_path, split))}")
# Out:
# Classes in train: ['heron', 'vulture', 'bird indian_bustard', 'bird albatross', 'animal hornbill', 'hornbill', 'bird hornbill', 'albatross']
# Classes in val: ['heron', 'vulture', 'bird indian_bustard', 'bird albatross', 'animal hornbill', 'hornbill', 'bird hornbill', 'albatross']
# Classes in test: ['heron', 'vulture', 'bird indian_bustard', 'bird albatross', 'animal hornbill', 'hornbill', 'bird hornbill', 'albatross']

# %%
import os

# Define dataset path
dataset_path = "/content/data"

# Define class name mapping
class_mapping = {
    "bird hornbill": "hornbill",
    "animal hornbill": "hornbill",
    "bird indian_bustard": "indian_bustard",
    "bird albatross": "albatross"
}

# Iterate over train, val, and test splits
for split in ["train", "val", "test"]:
    split_path = os.path.join(dataset_path, split)

    for old_class in os.listdir(split_path):
        old_class_path = os.path.join(split_path, old_class)

        if old_class in class_mapping:
            new_class = class_mapping[old_class]
            new_class_path = os.path.join(split_path, new_class)

            # Merge folders if new_class already exists
            if os.path.exists(new_class_path):
                for file in os.listdir(old_class_path):
                    os.rename(os.path.join(old_class_path, file), os.path.join(new_class_path, file))
                os.rmdir(old_class_path)  # Remove old empty folder
            else:
                os.rename(old_class_path, new_class_path)

print("✅ Dataset class names cleaned successfully!")
# Out:
# ✅ Dataset class names cleaned successfully!

# %%
for split in ['train', 'val', 'test']:
    print(f"Classes in {split}: {os.listdir(os.path.join(dataset_path, split))}")
# Out:
# Classes in train: ['heron', 'vulture', 'indian_bustard', 'hornbill', 'albatross']
# Classes in val: ['heron', 'vulture', 'indian_bustard', 'hornbill', 'albatross']
# Classes in test: ['heron', 'vulture', 'indian_bustard', 'hornbill', 'albatross']

# %% [markdown]
# ## Processing

# %% [markdown]
# Install Required Libraries

# %%
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Verify TensorFlow version
print("✅ TensorFlow version:", tf.__version__)
# Out:
# ✅ TensorFlow version: 2.18.0

# %% [markdown]
# Define Paths & Image Parameters

# %%
# Define dataset path
dataset_path = "/content/data"

# Image parameters
IMG_SIZE = 128  # Resize images to 128x128
BATCH_SIZE = 32  # Number of images per batch
COLOR_MODE = "grayscale"  # Convert to grayscale

# %% [markdown]
# Load Dataset using ImageDataGenerator

# %%
# Create ImageDataGenerator for preprocessing
datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values

# Load train, validation, and test sets
train_generator = datagen.flow_from_directory(
    os.path.join(dataset_path, "train"),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode=COLOR_MODE,
    class_mode="categorical"
)

val_generator = datagen.flow_from_directory(
    os.path.join(dataset_path, "val"),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode=COLOR_MODE,
    class_mode="categorical"
)

test_generator = datagen.flow_from_directory(
    os.path.join(dataset_path, "test"),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode=COLOR_MODE,
    class_mode="categorical",
    shuffle=False  # No shuffling for test set
)

print("✅ Dataset loaded successfully!")
# Out:
# Found 4489 images belonging to 5 classes.
# Found 1380 images belonging to 5 classes.
# Found 461 images belonging to 5 classes.
# ✅ Dataset loaded successfully!

# %% [markdown]
# Verify Image Samples

# %%
# Get a batch of images and labels
images, labels = next(train_generator)

# Plot sample images
plt.figure(figsize=(10, 5))
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i].squeeze(), cmap="gray")  # Squeeze removes extra dimension
    plt.axis("off")
plt.show()

# %% [markdown]
# ## Model Building

# %% [markdown]
# Define and Compile the CNN Model

# %% [markdown]
# Import Required Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Number of classes (adjust if needed)
NUM_CLASSES = len(train_generator.class_indices)

# Define the CNN model
model = models.Sequential([
    # First Conv Block
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 1)),
    layers.MaxPooling2D((2, 2)),

    # Second Conv Block
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Third Conv Block
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Flatten & Fully Connected Layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),  # Prevent overfitting
    layers.Dense(NUM_CLASSES, activation='softmax')  # Multi-class classification
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Model Summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ...

# %% [markdown]
# Train the model

# %%
EPOCHS = 20  # Adjust based on performance

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.3374 - loss: 1.3666 - val_accuracy: 0.4775 - val_loss: 1.2195
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.4612 - loss: 1.1921 - val_accuracy: 0.5775 - val_loss: 1.0576
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.5201 - loss: 1.1061 - val_accuracy: 0.5884 - val_loss: 0.9991
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.5328 - loss: 1.0355 - val_accuracy: 0.5877 - val_loss: 0.9971
# Epoch 5/20
# ...

# %% [markdown]
# Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.5895 - loss: 3.7968
# ✅ Test Accuracy: 54.66%

# %% [markdown]
# ##------------------------------------------------------------------------------

# %% [markdown]
# ## Improve Model Performance

# %% [markdown]
# Apply Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Updated ImageDataGenerator with Augmentation
datagen_augmented = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Re-load train data with augmentation
train_generator = datagen_augmented.flow_from_directory(
    os.path.join(dataset_path, "train"),
    target_size=(128, 128),
    batch_size=32,
    color_mode="grayscale",
    class_mode="categorical"
)
# Out:
# Found 4489 images belonging to 5 classes.

# %% [markdown]
# Build a Deeper CNN Model

# %%
from tensorflow.keras import layers, models

# Define Improved CNN Model
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(256, (3, 3), activation='relu'),  # New layer
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# Compile Model with Adaptive Learning Rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Model Summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 126, 126, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 126, 126, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# Train the Improved Model

# %%
EPOCHS = 30  # Increase training time for better learning

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.3629 - loss: 2.8686 - val_accuracy: 0.3159 - val_loss: 2.4164
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.4224 - loss: 1.3231 - val_accuracy: 0.2783 - val_loss: 2.9907
# Epoch 3/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.4340 - loss: 1.2759 - val_accuracy: 0.3616 - val_loss: 1.4317
# Epoch 4/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.4488 - loss: 1.2154 - val_accuracy: 0.4493 - val_loss: 1.1986
# Epoch 5/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.4478 - loss: 1.2179 - val_accuracy: 0.5239 - val_loss: 1.1414
# Epoch 6/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.4861 - loss: 1.1753 - val_accuracy: 0.5928 - val_loss: 0.9954
# Epoch 7/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.4820 - loss: 1.1648 - val_accuracy: 0.5413 - val_loss: 1.0746
# Epoch 8/30
# ...

# %% [markdown]
# Evaluate Again

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"✅ New Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 633ms/step - accuracy: 0.4793 - loss: 1.4448
# ✅ New Test Accuracy: 55.75%

# %% [markdown]
# ##----------------------------------------------------------------------------------

# %% [markdown]
# ## Use a Pretrained Model (Transfer Learning)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D

# Load Pretrained MobileNetV2 (without top layers)
# Changed input_shape to (128, 128, 3)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze the base model layers (so they don’t get updated)
base_model.trainable = False

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Define new model
model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Re-load train data with color_mode='rgb'
train_generator = datagen_augmented.flow_from_directory(
    os.path.join(dataset_path, "train"),
    target_size=(128, 128),
    batch_size=32,
    color_mode="rgb", # Changed color_mode to 'rgb'
    class_mode="categorical"
)
val_generator = datagen.flow_from_directory(
    os.path.join(dataset_path, "val"),
    target_size=(128, 128),
    batch_size=32,
    color_mode="rgb", # Changed color_mode to 'rgb'
    class_mode="categorical"
)
test_generator = datagen.flow_from_directory(
    os.path.join(dataset_path, "test"),
    target_size=(128, 128),
    batch_size=32,
    color_mode="rgb",# Changed color_mode to 'rgb'
    class_mode="categorical",
    shuffle=False  # No shuffling for test set
)

# Train model
history = model.fit(train_generator, validation_data=val_generator, epochs=20)

# Evaluate
test_loss, test_acc = model.evaluate(test_generator)
print(f"✅ New Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Found 4489 images belonging to 5 classes.
# Found 1380 images belonging to 5 classes.
# Found 461 images belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 94s 616ms/step - accuracy: 0.3855 - loss: 1.6357 - val_accuracy: 0.8428 - val_loss: 0.4824
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 84s 597ms/step - accuracy: 0.6364 - loss: 0.8971 - val_accuracy: 0.9051 - val_loss: 0.3390
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 85s 604ms/step - accuracy: 0.6955 - loss: 0.7497 - val_accuracy: 0.9225 - val_loss: 0.2694
# Epoch 4/20
# ...
